# %%
#Add repo path to the system path
from pathlib import Path
import os, sys
repo_path= Path.cwd().resolve()
while '.gitignore' not in os.listdir(repo_path): # while not in the root of the repo
    repo_path = repo_path.parent #go up one level
sys.path.insert(0,str(repo_path)) if str(repo_path) not in sys.path else None

import omidb
from pathlib import Path
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import pydicom
import yaml
from pydicom.pixel_data_handlers.util import apply_voi_lut

# %% [markdown]
# # Dataset analysis
#
#      The dataset folder is being mounted to padel from mia server.

# %% [markdown]
# To start we want to create a db object that contains all the clients found in the omi-db path. <br>
# The second step is to create a list of all the clients that are in the omi-db path. <br>

# %%
#define the path to the dataset
reading_path = '/mnt/mia_images/breast/omi-db/image_db/sharing/omi-db'
#db = omidb.DB(reading_path, clients=['demd111011'])
db = omidb.DB(data_dir=Path(reading_path) / 'data', image_dir=Path(reading_path) / 'images')

#save clients in a list
clients = [client for client in db]
#The number of clients/petients
len(clients)
# Out:
# 6000

# %%
db._image_dir
# Out:
# PosixPath('/mnt/mia_images/breast/omi-db/image_db/sharing/omi-db/images')

# %% [markdown]
# ## Structure of the OMI-DB dataset object

# %% [markdown]
# A <ins> **client** </ins>. represents a patient and can have one or more episodes. <br>
#
# - The client object gives information about the client such as:
#     - The client id
#     - A list of episodes
#     - The site (hospital) name
#     - The client's status (benign, malignant, normal, interval cancer)
#
# Let's take a client exmaple and analyze it:

# %%
client_num = 0
#get a client
client_ex = clients[client_num]
print(f'The client id is: {client_ex.id}')
print(f'The client number of episodes is: {len(client_ex.episodes)}')
print(f'The name of the site is: {client_ex.site}')
print(f'The client status is: {client_ex.status.value}')
# Out:
# The client id is: demd59120
# The client number of episodes is: 3
# The name of the site is: jarv
# The client status is: Normal

# %% [markdown]
# We can also access the nbss data using the client id.
# This contains redudant information as:
# - client id
# - client status,
#
# but also new information of the lower level of the dataset.

# %%
nbss_data = db._nbss(client_ex.id)
keys = list(nbss_data.keys())
print(keys)
nbss_data
# nbss_data[keys[3]]
# Out:
# ['9985', '9993', 'ClientID', '9999', 'Classification']
# {'9985': {'EpisodeOpenedDate': '1983-06-30',
#   'EpisodeIsClosed': 'Y',
#   'EpisodeType': 'R',
#   'PatientAge': 56,
#   'AccessionID': 'CRY588949914, CRY2455893143',
#   'EpisodeClosedDate': '1983-08-21',
#   'EpisodeAction': 'RR',
#   'StudyList': '1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.260.0',
#   'SCREENING': {'diagnosticsetoutcome': None,
#    'Opinion': None,
#    'left_opinion': 'Normal',
#    'R': {'SizeMm': None,
#     'FilmReader1Opinion': 'N',
#     'FilmRecommendedActions': 'RR RR',
#     'FilmReader1RecAction': 'RR',
#     'NumberOfRepeats': None,
#     'Opinion': 'RN',
#     'FilmReaderOpinions': 'N',
#     'EquipmentMakeModel': 'Hologic Selenia',
#     'FinalAction': 'RR',
#     'Microcalcification': None,
#     'DateTaken': '1983-08-17',
#     'FilmReader3RecAction': None,
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'RR',
#     'EquipmentUsed': '16',
#     'FilmReader2Opinion': 'N',
#     'SideCode': 'R',
#     'RepeatReason': None,
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD87 RD65',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'L': {'SizeMm': None,
#     'FilmReader1Opinion': 'N',
#     'FilmRecommendedActions': 'RR RR',
#     'FilmReader1RecAction': 'RR',
#     'NumberOfRepeats': None,
#     'Opinion': 'RN',
#     'FilmReaderOpinions': 'N',
#     'EquipmentMakeModel': 'Hologic Selenia',
#     'FinalAction': 'RR',
#     'Microcalcification': None,
#     'DateTaken': '1983-08-17',
#     'FilmReader3RecAction': None,
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'RR',
#     'EquipmentUsed': '16',
#     'FilmReader2Opinion': 'N',
#     'SideCode': 'L',
#     'RepeatReason': None,
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD87 RD65',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'right_opinion': 'Normal',
#    'dateperformed': None}},
#  '9993': {'EpisodeOpenedDate': '1980-06-30',
#   'EpisodeIsClosed': 'Y',
#   'EpisodeType': 'R',
#   'PatientAge': 56,
#   'AccessionID': 'CRY3853226272',
#   'EpisodeClosedDate': '1980-08-12',
#   'EpisodeAction': 'RR',
#   'StudyList': '1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.239.0',
#   'SCREENING': {'diagnosticsetoutcome': None,
#    'Opinion': None,
#    'left_opinion': 'Normal',
#    'R': {'SizeMm': None,
#     'FilmReader1Opinion': 'N',
#     'FilmRecommendedActions': 'RR RR',
#     'FilmReader1RecAction': 'RR',
#     'NumberOfRepeats': None,
#     'Opinion': 'RN',
#     'FilmReaderOpinions': 'N',
#     'EquipmentMakeModel': 'Hologic Selenia',
#     'FinalAction': 'RR',
#     'Microcalcification': None,
#     'DateTaken': '1980-08-04',
#     'FilmReader3RecAction': None,
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'RR',
#     'EquipmentUsed': '15',
#     'FilmReader2Opinion': 'N',
#     'SideCode': 'R',
#     'RepeatReason': None,
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD28 RD46',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'L': {'SizeMm': None,
#     'FilmReader1Opinion': 'N',
#     'FilmRecommendedActions': 'RR RR',
#     'FilmReader1RecAction': 'RR',
#     'NumberOfRepeats': '1',
#     'Opinion': 'RN',
#     'FilmReaderOpinions': 'N',
#     'EquipmentMakeModel': 'Hologic Selenia',
#     'FinalAction': 'RR',
#     'Microcalcification': None,
#     'DateTaken': '1980-08-04',
#     'FilmReader3RecAction': None,
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'RR',
#     'EquipmentUsed': '15',
#     'FilmReader2Opinion': 'N',
#     'SideCode': 'L',
#     'RepeatReason': 'R1A',
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD28 RD46',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'right_opinion': 'Normal',
#    'dateperformed': None}},
#  'ClientID': 'demd59120',
#  '9999': {'EpisodeOpenedDate': '1977-07-12',
#   'EpisodeIsClosed': 'Y',
#   'EpisodeType': 'F',
#   'PatientAge': 56,
#   'AccessionID': 'CRY4214298572, CRY3387381949',
#   'EpisodeClosedDate': '1977-08-31',
#   'EpisodeAction': 'RR',
#   'StudyList': '1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.222.0',
#   'SCREENING': {'diagnosticsetoutcome': None,
#    'Opinion': None,
#    'left_opinion': 'Normal',
#    'R': {'SizeMm': None,
#     'FilmReader1Opinion': 'N',
#     'FilmRecommendedActions': 'RR RR',
#     'FilmReader1RecAction': 'RR',
#     'NumberOfRepeats': None,
#     'Opinion': 'RN',
#     'FilmReaderOpinions': 'N',
#     'EquipmentMakeModel': 'Hologic Selenia',
#     'FinalAction': 'RR',
#     'Microcalcification': None,
#     'DateTaken': '1977-08-22',
#     'FilmReader3RecAction': None,
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'RR',
#     'EquipmentUsed': '18',
#     'FilmReader2Opinion': 'N',
#     'SideCode': 'R',
#     'RepeatReason': None,
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD37 RD47',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'L': {'SizeMm': None,
#     'FilmReader1Opinion': 'N',
#     'FilmRecommendedActions': 'RR RR',
#     'FilmReader1RecAction': 'RR',
#     'NumberOfRepeats': None,
#     'Opinion': 'RN',
#     'FilmReaderOpinions': 'N',
#     'EquipmentMakeModel': 'Hologic Selenia',
#     'FinalAction': 'RR',
#     'Microcalcification': None,
#     'DateTaken': '1977-08-22',
#     'FilmReader3RecAction': None,
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'RR',
#     'EquipmentUsed': '18',
#     'FilmReader2Opinion': 'N',
#     'SideCode': 'L',
#     'RepeatReason': None,
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD37 RD47',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'right_opinion': 'Normal',
#    'dateperformed': None}},
#  'Classification': 'N'}

# %% [markdown]
# The next interesting object is the episode <ins> **object** </ins>. <br>
# Episodes contain a set of medical procedures or events associated with the treatment or diagnosis. <br>
# - The episode object contains:
#     - The episode id (unique for within client)
#     - Events object: a set of medical procedures or events associated wiith the episode
#     - Studies list: studies are collections of screening and diagnostic images

# %%
episode_num = 1
#Get the first episode of the client as example
episode_ex = client_ex.episodes[episode_num]
#get id of the episode
print(f'The episode id is: {episode_ex.id}')
print(f'The number of studies is: {len(episode_ex.studies)}') if episode_ex.studies else print('No studies')
print(f'The episode type is: {episode_ex.type.value}')
print(f'The episode action is: {episode_ex.action.value}') if episode_ex.action else print('No action')
print(f'The episode opened date is: {episode_ex.opened_date}')
print(f'The episode closed date is: {episode_ex.closed_date}')
print(f'is the episode closed?: {episode_ex.is_closed}')
print(f'number of lesions in the episode: {len(episode_ex.lesions)}') if episode_ex.lesions else print('No lesions')

# Addiitioanl properties can be given back:
print(f'The episode has benign opinions?: {episode_ex.has_benign_opinions}')
print(f'The episode has malignant opinions?: {episode_ex.has_malignant_opinions}')
#print seperator
print('-----------------------------')
# Get the events object, it shows all the events that happened in the episode
events_ex = episode_ex.events
print(f'All the events in the episode: \n{events_ex}')
print(events_ex)
# Out:
# The episode id is: 9993
# The number of studies is: 1
# The episode type is: Routine Recall
# The episode action is: Routine recall for screening
# The episode opened date is: 1980-06-30
# The episode closed date is: 1980-08-12
# is the episode closed?: True
# No lesions
# The episode has benign opinions?: False
# The episode has malignant opinions?: False
# -----------------------------
# All the events in the episode:
# Events(screening=[Screening(left_opinion=<SideOpinion.ON: 'Normal'>, right_opinion=<SideOpinion.ON: 'Normal'>, dates=[datetime.date(1980, 8, 4)], left=BreastScreeningData(date=datetime.date(1980, 8, 4), equipment_make_model='Hologic Selenia', opinion=<Opinion.RN: 'R Normal'>), right=BreastScreeningData(date=datetime.date(1980, 8, 4), equipment_make_model='Hologic Selenia', opinion=<Opinion.RN: 'R Normal'>))], assessment=None, clinical=None, biopsy_wide=None, biopsy_fine=None, surgery=None)
# Events(screening=[Screening(left_opinion=<SideOpinion.ON: 'Normal'>, right_opinion=<SideOpinion.ON: 'Normal'>, dates=[datetime.date(1980, 8, 4)], left=BreastScreeningData(date=datetime.date(1980, 8, 4), equipment_make_model='Hologic Selenia', opinion=<Opinion.RN: 'R Normal'>), right=BreastScreeningData(date=datetime.date(1980, 8, 4), equipment_make_model='Hologic Selenia', opinion=<Opinion.RN: 'R Normal'>))], assessment=None, clinical=None, biopsy_wide=None, biopsy_fine=None, surgery=None)

# %%
# nbss data of the same episode
episode_data = nbss_data.get(episode_ex.id, {})
for key, value in episode_data.items():
    print(f'{key}: {value}')
# Out:
# EpisodeOpenedDate: 1980-06-30
# EpisodeIsClosed: Y
# EpisodeType: R
# PatientAge: 56
# AccessionID: CRY3853226272
# EpisodeClosedDate: 1980-08-12
# EpisodeAction: RR
# StudyList: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.239.0
# SCREENING: {'diagnosticsetoutcome': None, 'Opinion': None, 'left_opinion': 'Normal', 'R': {'SizeMm': None, 'FilmReader1Opinion': 'N', 'FilmRecommendedActions': 'RR RR', 'FilmReader1RecAction': 'RR', 'NumberOfRepeats': None, 'Opinion': 'RN', 'FilmReaderOpinions': 'N', 'EquipmentMakeModel': 'Hologic Selenia', 'FinalAction': 'RR', 'Microcalcification': None, 'DateTaken': '1980-08-04', 'FilmReader3RecAction': None, 'FilmReader4RecAction': None, 'FilmReader2RecAction': 'RR', 'EquipmentUsed': '15', 'FilmReader2Opinion': 'N', 'SideCode': 'R', 'RepeatReason': None, 'FilmReader4Opinion': None, 'MicrocalcWithMass': None, 'Mass': None, 'FilmReader5Opinion': None, 'FilmReaders': 'RD28 RD46', 'FilmReader5RecAction': None, 'FilmReader3Opinion': None}, 'L': {'SizeMm': None, 'FilmReader1Opinion': 'N', 'FilmRecommendedActions': 'RR RR', 'FilmReader1RecAction': 'RR', 'NumberOfRepeats': '1', 'Opinion': 'RN', 'FilmReaderOpinions': 'N', 'EquipmentMakeModel': 'Hologic Selenia', 'FinalAction': 'RR', 'Microcalcification': None, 'DateTaken': '1980-08-04', 'FilmReader3RecAction': None, 'FilmReader4RecAction': None, 'FilmReader2RecAction': 'RR', 'EquipmentUsed': '15', 'FilmReader2Opinion': 'N', 'SideCode': 'L', 'RepeatReason': 'R1A', 'FilmReader4Opinion': None, 'MicrocalcWithMass': None, 'Mass': None, 'FilmReader5Opinion': None, 'FilmReaders': 'RD28 RD46', 'FilmReader5RecAction': None, 'FilmReader3Opinion': None}, 'right_opinion': 'Normal', 'dateperformed': None}

# %% [markdown]
# The next structures are <ins> **events** </ins> and <ins> **studies** </ins>. <br>
# Studies are imaging examinations made out of <ins>series</ins>. Each serie contains a set of <ins> **images** </ins>. <br>
#
#     Note that not all episodes may have studies!!
# This is important to consider, as we care about the episodes that have images (therefore, studies). <br>

# %%
# Get the first study of the episode as example
study_num = 0
if episode_ex.studies:
    study_ex = episode_ex.studies[study_num]
    print(f'The study id is: {study_ex.id}')
    print(f'The number of series is: {len(study_ex.series)}')
    print(f'The event type(s) is: {study_ex.event_type}')
    print(f'The study date is: {study_ex.date}')
    
else:
    print('No studies')
# Out:
# The study id is: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.239.0
# The number of series is: 10
# The event type(s) is: [<Event.screening: 'screening'>]
# The study date is: 1980-08-04

# %% [markdown]
# Series are the next and final subsrtucture of the dataset. <br>
# It is a <ins> **collection of images** </ins> taken during one examination by one modality, for a given position of the patient in the acquisition device. <br>
# In full-field digital mammography, each image is usually associated with one series. <br>
# - The series object contains:
#     - The series id
#     - The list of images

# %%
for series_num in range(0,len(study_ex.series)):
    
    # Get the first series of the study as example
    series_ex = study_ex.series[series_num]
    print(f'The series id is: {series_ex.id}')
    print(f'The number of images is: {series_ex.num_images}')
    #All images in the series can be plotted using
    plt.figure(figsize=(10,10))
    series_ex.plot()
    plt.title(f'Series {series_ex.id}')

    print(f'The list of marks in the image is: {series_ex.images[0].marks}')
# Out:
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.258.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.259.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.246.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.255.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.240.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.254.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.250.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.251.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.247.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.243.0
# The number of images is: 1
# The list of marks in the image is: []

# %% [markdown]
# The images are the elemental elements of the dataset (from the point of view of our analysis). <br>
# Image objects contain all the relevant information about the image. <br>
#
# - The image object contains:
#     - The image id: unique for each image
#     - Dicom path
#     - JSON file path with the DICOM metadata
#     - A dictionary containing the DICOM metadata
#     - A parsed version of the DICOM file

# %%
series_ex = study_ex.series[0]
image_num = 0 # usually there is just one image in the series
# get the first image of the series as example
image_ex = series_ex.images[image_num]

print(f'The image id is: {image_ex.id}')
print(f'The dicom path is: {image_ex.dcm}')
# print(f'The JSON path is: {image_ex.json_path}')
# print(f'The list of marks in the image is: {image_ex.marks}')
# Out:
# The image id is: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.257.0
# The dicom path is: Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 208
# (0002, 0001) File Meta Information Version       OB: b'\x01\x00'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital Mammography X-Ray Image Storage - For Processing
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.257.0
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.22213.1.143
# (0002, 0016) Source Application Entity Title     AE: 'DCMPseudonymiser'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008, 0016) SOP Class UID                       UI: Digital Mammography X-Ray Image Storage - For Processing
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.257.0
# (0008, 0020) Study Date                          DA: '19800804'
# (0008, 0021) Series Date                         DA: '19800804'
# (0008, 0022) Acquisition Date                    DA: '19800804'
# (0008, 0023) Content Date                        DA: '19800804'
# (0008, 0030) Study Time                          TM: '000000'
# (0008, 0031) Series Time                         TM: '000000'
# (0008, 0032) Acquisition Time                    TM: '000000'
# (0008, 0033) Content Time                        TM: '000000'
# (0008, 0050) Accession Number                    SH: 'Data anonymised'
# (0008, 0060) Modality                            CS: 'MG'
# (0008, 0061) Modalities in Study                 CS: 'MG'
# (0008, 0068) Presentation Intent Type            CS: 'FOR PROCESSING'
# (0008, 0070) Manufacturer                        LO: 'HOLOGIC, Inc.'
# (0008, 0080) Institution Name                    LO: 'Data anonymised'
# (0008, 0081) Institution Address                 ST: 'Data anonymised'
# (0008, 0090) Referring Physician's Name          PN: 'Data anonymised^^^^'
# (0008, 1010) Station Name                        SH: 'Data anonymised'
# (0008, 1030) Study Description                   LO: 'XR Screening mammogram Both'
# (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'XSCMB'
#    (0008, 0102) Coding Scheme Designator            SH: 'SECTRA'
#    (0008, 0104) Code Meaning                        LO: 'XR Screening mammogram Both'
#    ---------
# (0008, 103e) Series Description                  LO: 'L CC'
# (0008, 1048) Physician(s) of Record              PN: 'Data anonymised^^^^'
# (0008, 1060) Name of Physician(s) Reading Study  PN: 'Data anonymised^^^^'
# (0008, 1070) Operators' Name                     PN: 'Data anonymised^^^^'
# (0008, 1080) Admitting Diagnoses Description     LO: 'Data anonymised'
# (0008, 1090) Manufacturer's Model Name           LO: 'Lorad Selenia'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.826.0.1.3680043.9.3218.1.1.26950057.4962.1510228559379.699.0
#    ---------
# (0008, 2111) Derivation Description              ST: 'Data anonymised'
# (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'T-04000'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'Breast'
#    ---------
# (0010, 0010) Patient's Name                      PN: 'demd59120'
# (0010, 0020) Patient ID                          LO: 'demd59120'
# (0010, 0030) Patient's Birth Date                DA: '01010101'
# (0010, 0032) Patient's Birth Time                TM: '000000'
# (0010, 0040) Patient's Sex                       CS: ''
# (0010, 1000) Other Patient IDs                   LO: 'Data anonymised'
# (0010, 1001) Other Patient Names                 PN: 'Data anonymised^^^^'
# (0010, 1010) Patient's Age                       AS: '052Y'
# (0010, 1090) Medical Record Locator              LO: 'Data anonymised'
# (0010, 2160) Ethnic Group                        SH: ''
# (0010, 21b0) Additional Patient History          LT: 'Data anonymised'
# (0010, 4000) Patient Comments                    LT: 'Data anonymised'
# (0012, 0064)  De-identification Method Code Sequence  5 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '210004'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Remove all descriptors'
#    ---------
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '210001'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Remap UIDs'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'BREAST'
# (0018, 0060) KVP                                 DS: '28.0'
# (0018, 1000) Device Serial Number                LO: 'SN000000'
# (0018, 1008) Gantry ID                           LO: 'Data anonymised'
# (0018, 1020) Software Versions                   LO: 'Data anonymised'
# (0018, 1030) Protocol Name                       LO: 'Data anonymised'
# (0018, 1110) Distance Source to Detector         DS: '660.0'
# (0018, 1111) Distance Source to Patient          DS: '640.0'
# (0018, 1114) Estimated Radiographic Magnificatio DS: '1.0'
# (0018, 1147) Field of View Shape                 CS: 'RECTANGLE'
# (0018, 1150) Exposure Time                       IS: '1114'
# (0018, 1151) X-Ray Tube Current                  IS: '100'
# (0018, 1152) Exposure                            IS: '111'
# (0018, 1153) Exposure in uAs                     IS: '111400'
# (0018, 1164) Imager Pixel Spacing                DS: [.070, .070]
# (0018, 1166) Grid                                CS: 'HTC_IN'
# (0018, 1190) Focal Spot(s)                       DS: '0.3'
# (0018, 1191) Anode Target Material               CS: 'TUNGSTEN'
# (0018, 11a0) Body Part Thickness                 DS: '51.0'
# (0018, 11a2) Compression Force                   DS: '63.00019'
# (0018, 1200) Date of Last Calibration            DA: '20141024'
# (0018, 1201) Time of Last Calibration            TM: '105725'
# (0018, 1400) Acquisition Device Processing Descr LO: 'Data anonymised'
# (0018, 1401) Acquisition Device Processing Code  LO: ''
# (0018, 1405) Relative X-Ray Exposure             IS: '563'
# (0018, 1508) Positioner Type                     CS: 'MAMMOGRAPHIC'
# (0018, 1510) Positioner Primary Angle            DS: '0.0'
# (0018, 1511) Positioner Secondary Angle          DS: None
# (0018, 5101) View Position                       CS: 'CC'
# (0018, 6000) Sensitivity                         DS: None
# (0018, 7000) Detector Conditions Nominal Flag    CS: 'YES'
# (0018, 7001) Detector Temperature                DS: '30.0'
# (0018, 7004) Detector Type                       CS: 'DIRECT'
# (0018, 7005) Detector Configuration              CS: 'AREA'
# (0018, 7006) Detector Description                LT: Array of 48 elements
# (0018, 700a) Detector ID                         SH: 'DET00000'
# (0018, 700c) Date of Last Detector Calibration   DA: '19000101'
# (0018, 700e) Time of Last Detector Calibration   TM: '000000'
# (0018, 7024) Detector Active Shape               CS: 'RECTANGLE'
# (0018, 7026) Detector Active Dimension(s)        DS: [250, 286]
# (0018, 7030) Field of View Origin                DS: [377, 1024]
# (0018, 7032) Field of View Rotation              DS: '180.0'
# (0018, 7034) Field of View Horizontal Flip       CS: 'NO'
# (0018, 7048) Grid Period                         DS: None
# (0018, 7050) Filter Material                     CS: 'RHODIUM'
# (0018, 7052) Filter Thickness Minimum            DS: '0.057'
# (0018, 7054) Filter Thickness Maximum            DS: '0.057'
# (0018, 7060) Exposure Control Mode               CS: 'AUTO_FILTER'
# (0018, 7062) Exposure Control Mode Description   LT: 'LORAD AUTO AEC'
# (0018, 7064) Exposure Status                     CS: 'NORMAL'
# (0019, 0010) Private Creator                     LO: 'LORAD Selenia'
# (0019, 1006) [Paddle ID]                         OB: b'019 '
# (0019, 1007) [Paddle Position]                   OB: b'0 '
# (0019, 1008) [Collimation Size]                  OB: b'001 '
# (0019, 1026) [Unknown]                           OB: b'18cm x 24cm fast'
# (0019, 1027) [Unknown]                           OB: b'C '
# (0019, 1028) [Unknown]                           OB: b'18cm x 24cm '
# (0019, 1029) [Unknown]                           OB: Array of 32 elements
# (0019, 1030) [Unknown]                           OB: b'd\x00'
# (0019, 1031) [Unknown]                           OB: b'S\x00'
# (0019, 1032) [Unknown]                           OB: b'\xfa\x03'
# (0019, 1033) [Unknown]                           OB: b'\x11\x02'
# (0019, 1034) [Unknown]                           OB: b'\xa1\x01'
# (0019, 1035) [Unknown]                           OB: b'\xff\xff'
# (0019, 1041) [Unknown]                           OB: b'563 '
# (0019, 1050) [Unknown]                           OB: None
# (0019, 1051) [Unknown]                           OB: None
# (0019, 1052) [Unknown]                           OB: None
# (0019, 1053) [Unknown]                           OB: None
# (0019, 1070) [Unknown]                           OB: None
# (0019, 1071) [Unknown]                           OB: None
# (0019, 1080) Private tag data                    UN: b'0224'
# (0019, 1081) Private tag data                    UN: b'1756'
# (0019, 1082) Private tag data                    UN: b'PMK '
# (0019, 1083) Private tag data                    UN: b'L CC            '
# (0019, 1084) Private tag data                    UN: b'0000'
# (0019, 1085) Private tag data                    UN: b'0000'
# (0019, 1086) Private tag data                    UN: b'    '
# (0019, 1087) Private tag data                    UN: b'                '
# (0019, 1088) Private tag data                    UN: b'0000'
# (0019, 1089) Private tag data                    UN: b'0000'
# (0019, 1090) Private tag data                    UN: b'    '
# (0019, 1091) Private tag data                    UN: b'                '
# (0019, 1097) Private tag data                    UN: b'YES '
# (0019, 1098) Private tag data                    UN: b'NO  '
# (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.239.0
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.258.0
# (0020, 0010) Study ID                            SH: 'Data anonymised'
# (0020, 0011) Series Number                       IS: '5'
# (0020, 0012) Acquisition Number                  IS: None
# (0020, 0013) Instance Number                     IS: '75'
# (0020, 0020) Patient Orientation                 CS: ['A', 'R']
# (0020, 0060) Laterality                          CS: ''
# (0020, 0062) Image Laterality                    CS: 'L'
# (0020, 1002) Images in Acquisition               IS: '1'
# (0020, 1070) Other Study Numbers                 IS: None
# (0020, 4000) Image Comments                      LT: 'Data anonymised'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME1'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0010) Rows                                US: 3328
# (0028, 0011) Columns                             US: 2560
# (0028, 0030) Pixel Spacing                       DS: [0.0700, 0.0700]
# (0028, 0034) Pixel Aspect Ratio                  IS: [180, 180]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 14
# (0028, 0102) High Bit                            US: 13
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0301) Burned In Annotation                CS: 'NO'
# (0028, 1040) Pixel Intensity Relationship        CS: 'LIN'
# (0028, 1041) Pixel Intensity Relationship Sign   SS: 1
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'US'
# (0028, 1300) Breast Implant Present              CS: 'NO'
# (0028, 1350) Partial View                        CS: ''
# (0028, 1351) Partial View Description            ST: ''
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0032, 000c) Study Priority ID                   CS: ''
# (0032, 1000) Scheduled Study Start Date          DA: ''
# (0032, 1001) Scheduled Study Start Time          TM: ''
# (0032, 1030) Reason for Study                    LO: 'SCREENING'
# (0032, 1032) Requesting Physician                PN: 'Data anonymised^^^^'
# (0032, 1060) Requested Procedure Description     LO: 'Data anonymised'
# (0032, 4000) Study Comments                      LT: 'Data anonymised'
# (0038, 0010) Admission ID                        LO: 'Data anonymised'
# (0038, 0016) Route of Admissions                 LO: ''
# (0038, 0020) Admitting Date                      DA: '19000101'
# (0038, 0021) Admitting Time                      TM: '000000'
# (0038, 0300) Current Patient Location            LO: 'Data anonymised'
# (0040, 0253) Performed Procedure Step ID         SH: 'Data anonymised'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Screening Mammography'
# (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#    (0040, 0009) Scheduled Procedure Step ID         SH: '0'
#    (0040, 1001) Requested Procedure ID              SH: 'Data anonymised'
#    ---------
# (0040, 0302) Entrance Dose                       US: 0
# (0040, 0314) Half Value Layer                    DS: '0.552'
# (0040, 0316) Organ Dose                          DS: '0.0133'
# (0040, 0318) Organ Exposed                       CS: 'BREAST'
# (0040, 0555)  Acquisition Context Sequence  0 item(s) ----
# (0040, 1003) Requested Procedure Priority        SH: ''
# (0040, 1004) Patient Transport Arrangements      LO: 'Data anonymised'
# (0040, 1010) Names of Intended Recipients of Res PN: 'Data anonymised^^^^'
# (0040, 8302) Entrance Dose in mGy                DS: '4.67'
# (0050, 0004) Calibration Image                   CS: 'NO'
# (0054, 0220)  View Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'R-10242'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'cranio-caudal'
#    (0054, 0222)  View Modifier Code Sequence  0 item(s) ----
#    ---------
# (2050, 0020) Presentation LUT Shape              CS: 'INVERSE'
# (7fe0, 0010) Pixel Data                          OW: Array of 17039360 elements

# %%
image_ex.dcm
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 208
# (0002, 0001) File Meta Information Version       OB: b'\x01\x00'
# (0002, 0002) Media Storage SOP Class UID         UI: Digital Mammography X-Ray Image Storage - For Processing
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.257.0
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.3.6.1.4.1.22213.1.143
# (0002, 0016) Source Application Entity Title     AE: 'DCMPseudonymiser'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008, 0016) SOP Class UID                       UI: Digital Mammography X-Ray Image Storage - For Processing
# (0008, 0018) SOP Instance UID                    UI: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.257.0
# (0008, 0020) Study Date                          DA: '19800804'
# (0008, 0021) Series Date                         DA: '19800804'
# (0008, 0022) Acquisition Date                    DA: '19800804'
# (0008, 0023) Content Date                        DA: '19800804'
# (0008, 0030) Study Time                          TM: '000000'
# (0008, 0031) Series Time                         TM: '000000'
# (0008, 0032) Acquisition Time                    TM: '000000'
# (0008, 0033) Content Time                        TM: '000000'
# (0008, 0050) Accession Number                    SH: 'Data anonymised'
# (0008, 0060) Modality                            CS: 'MG'
# (0008, 0061) Modalities in Study                 CS: 'MG'
# (0008, 0068) Presentation Intent Type            CS: 'FOR PROCESSING'
# (0008, 0070) Manufacturer                        LO: 'HOLOGIC, Inc.'
# (0008, 0080) Institution Name                    LO: 'Data anonymised'
# (0008, 0081) Institution Address                 ST: 'Data anonymised'
# (0008, 0090) Referring Physician's Name          PN: 'Data anonymised^^^^'
# (0008, 1010) Station Name                        SH: 'Data anonymised'
# (0008, 1030) Study Description                   LO: 'XR Screening mammogram Both'
# (0008, 1032)  Procedure Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'XSCMB'
#    (0008, 0102) Coding Scheme Designator            SH: 'SECTRA'
#    (0008, 0104) Code Meaning                        LO: 'XR Screening mammogram Both'
#    ---------
# (0008, 103e) Series Description                  LO: 'L CC'
# (0008, 1048) Physician(s) of Record              PN: 'Data anonymised^^^^'
# (0008, 1060) Name of Physician(s) Reading Study  PN: 'Data anonymised^^^^'
# (0008, 1070) Operators' Name                     PN: 'Data anonymised^^^^'
# (0008, 1080) Admitting Diagnoses Description     LO: 'Data anonymised'
# (0008, 1090) Manufacturer's Model Name           LO: 'Lorad Selenia'
# (0008, 1110)  Referenced Study Sequence  1 item(s) ----
#    (0008, 1150) Referenced SOP Class UID            UI: Detached Study Management SOP Class
#    (0008, 1155) Referenced SOP Instance UID         UI: 1.2.826.0.1.3680043.9.3218.1.1.26950057.4962.1510228559379.699.0
#    ---------
# (0008, 2111) Derivation Description              ST: 'Data anonymised'
# (0008, 2218)  Anatomic Region Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'T-04000'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'Breast'
#    ---------
# (0010, 0010) Patient's Name                      PN: 'demd59120'
# (0010, 0020) Patient ID                          LO: 'demd59120'
# (0010, 0030) Patient's Birth Date                DA: '01010101'
# (0010, 0032) Patient's Birth Time                TM: '000000'
# (0010, 0040) Patient's Sex                       CS: ''
# (0010, 1000) Other Patient IDs                   LO: 'Data anonymised'
# (0010, 1001) Other Patient Names                 PN: 'Data anonymised^^^^'
# (0010, 1010) Patient's Age                       AS: '052Y'
# (0010, 1090) Medical Record Locator              LO: 'Data anonymised'
# (0010, 2160) Ethnic Group                        SH: ''
# (0010, 21b0) Additional Patient History          LT: 'Data anonymised'
# (0010, 4000) Patient Comments                    LT: 'Data anonymised'
# (0012, 0064)  De-identification Method Code Sequence  5 item(s) ----
#    (0008, 0100) Code Value                          SH: '113100'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Basic Application Confidentiality Profile'
#    ---------
#    (0008, 0100) Code Value                          SH: '210004'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Remove all descriptors'
#    ---------
#    (0008, 0100) Code Value                          SH: '113108'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Patient Characteristics Option'
#    ---------
#    (0008, 0100) Code Value                          SH: '210001'
#    (0008, 0102) Coding Scheme Designator            SH: '99PMP'
#    (0008, 0104) Code Meaning                        LO: 'Remap UIDs'
#    ---------
#    (0008, 0100) Code Value                          SH: '113107'
#    (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#    (0008, 0104) Code Meaning                        LO: 'Retain Longitudinal Temporal Information Modified Dates Option'
#    ---------
# (0018, 0015) Body Part Examined                  CS: 'BREAST'
# (0018, 0060) KVP                                 DS: '28.0'
# (0018, 1000) Device Serial Number                LO: 'SN000000'
# (0018, 1008) Gantry ID                           LO: 'Data anonymised'
# (0018, 1020) Software Versions                   LO: 'Data anonymised'
# (0018, 1030) Protocol Name                       LO: 'Data anonymised'
# (0018, 1110) Distance Source to Detector         DS: '660.0'
# (0018, 1111) Distance Source to Patient          DS: '640.0'
# (0018, 1114) Estimated Radiographic Magnificatio DS: '1.0'
# (0018, 1147) Field of View Shape                 CS: 'RECTANGLE'
# (0018, 1150) Exposure Time                       IS: '1114'
# (0018, 1151) X-Ray Tube Current                  IS: '100'
# (0018, 1152) Exposure                            IS: '111'
# (0018, 1153) Exposure in uAs                     IS: '111400'
# (0018, 1164) Imager Pixel Spacing                DS: [.070, .070]
# (0018, 1166) Grid                                CS: 'HTC_IN'
# (0018, 1190) Focal Spot(s)                       DS: '0.3'
# (0018, 1191) Anode Target Material               CS: 'TUNGSTEN'
# (0018, 11a0) Body Part Thickness                 DS: '51.0'
# (0018, 11a2) Compression Force                   DS: '63.00019'
# (0018, 1200) Date of Last Calibration            DA: '20141024'
# (0018, 1201) Time of Last Calibration            TM: '105725'
# (0018, 1400) Acquisition Device Processing Descr LO: 'Data anonymised'
# (0018, 1401) Acquisition Device Processing Code  LO: ''
# (0018, 1405) Relative X-Ray Exposure             IS: '563'
# (0018, 1508) Positioner Type                     CS: 'MAMMOGRAPHIC'
# (0018, 1510) Positioner Primary Angle            DS: '0.0'
# (0018, 1511) Positioner Secondary Angle          DS: None
# (0018, 5101) View Position                       CS: 'CC'
# (0018, 6000) Sensitivity                         DS: None
# (0018, 7000) Detector Conditions Nominal Flag    CS: 'YES'
# (0018, 7001) Detector Temperature                DS: '30.0'
# (0018, 7004) Detector Type                       CS: 'DIRECT'
# (0018, 7005) Detector Configuration              CS: 'AREA'
# (0018, 7006) Detector Description                LT: Array of 48 elements
# (0018, 700a) Detector ID                         SH: 'DET00000'
# (0018, 700c) Date of Last Detector Calibration   DA: '19000101'
# (0018, 700e) Time of Last Detector Calibration   TM: '000000'
# (0018, 7024) Detector Active Shape               CS: 'RECTANGLE'
# (0018, 7026) Detector Active Dimension(s)        DS: [250, 286]
# (0018, 7030) Field of View Origin                DS: [377, 1024]
# (0018, 7032) Field of View Rotation              DS: '180.0'
# (0018, 7034) Field of View Horizontal Flip       CS: 'NO'
# (0018, 7048) Grid Period                         DS: None
# (0018, 7050) Filter Material                     CS: 'RHODIUM'
# (0018, 7052) Filter Thickness Minimum            DS: '0.057'
# (0018, 7054) Filter Thickness Maximum            DS: '0.057'
# (0018, 7060) Exposure Control Mode               CS: 'AUTO_FILTER'
# (0018, 7062) Exposure Control Mode Description   LT: 'LORAD AUTO AEC'
# (0018, 7064) Exposure Status                     CS: 'NORMAL'
# (0019, 0010) Private Creator                     LO: 'LORAD Selenia'
# (0019, 1006) [Paddle ID]                         OB: b'019 '
# (0019, 1007) [Paddle Position]                   OB: b'0 '
# (0019, 1008) [Collimation Size]                  OB: b'001 '
# (0019, 1026) [Unknown]                           OB: b'18cm x 24cm fast'
# (0019, 1027) [Unknown]                           OB: b'C '
# (0019, 1028) [Unknown]                           OB: b'18cm x 24cm '
# (0019, 1029) [Unknown]                           OB: Array of 32 elements
# (0019, 1030) [Unknown]                           OB: b'd\x00'
# (0019, 1031) [Unknown]                           OB: b'S\x00'
# (0019, 1032) [Unknown]                           OB: b'\xfa\x03'
# (0019, 1033) [Unknown]                           OB: b'\x11\x02'
# (0019, 1034) [Unknown]                           OB: b'\xa1\x01'
# (0019, 1035) [Unknown]                           OB: b'\xff\xff'
# (0019, 1041) [Unknown]                           OB: b'563 '
# (0019, 1050) [Unknown]                           OB: None
# (0019, 1051) [Unknown]                           OB: None
# (0019, 1052) [Unknown]                           OB: None
# (0019, 1053) [Unknown]                           OB: None
# (0019, 1070) [Unknown]                           OB: None
# (0019, 1071) [Unknown]                           OB: None
# (0019, 1080) Private tag data                    UN: b'0224'
# (0019, 1081) Private tag data                    UN: b'1756'
# (0019, 1082) Private tag data                    UN: b'PMK '
# (0019, 1083) Private tag data                    UN: b'L CC            '
# (0019, 1084) Private tag data                    UN: b'0000'
# (0019, 1085) Private tag data                    UN: b'0000'
# (0019, 1086) Private tag data                    UN: b'    '
# (0019, 1087) Private tag data                    UN: b'                '
# (0019, 1088) Private tag data                    UN: b'0000'
# (0019, 1089) Private tag data                    UN: b'0000'
# (0019, 1090) Private tag data                    UN: b'    '
# (0019, 1091) Private tag data                    UN: b'                '
# (0019, 1097) Private tag data                    UN: b'YES '
# (0019, 1098) Private tag data                    UN: b'NO  '
# (0020, 000d) Study Instance UID                  UI: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.239.0
# (0020, 000e) Series Instance UID                 UI: 1.2.826.0.1.3680043.9.3218.1.1.22753672.1184.1537825861464.258.0
# (0020, 0010) Study ID                            SH: 'Data anonymised'
# (0020, 0011) Series Number                       IS: '5'
# (0020, 0012) Acquisition Number                  IS: None
# (0020, 0013) Instance Number                     IS: '75'
# (0020, 0020) Patient Orientation                 CS: ['A', 'R']
# (0020, 0060) Laterality                          CS: ''
# (0020, 0062) Image Laterality                    CS: 'L'
# (0020, 1002) Images in Acquisition               IS: '1'
# (0020, 1070) Other Study Numbers                 IS: None
# (0020, 4000) Image Comments                      LT: 'Data anonymised'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME1'
# (0028, 0006) Planar Configuration                US: 0
# (0028, 0010) Rows                                US: 3328
# (0028, 0011) Columns                             US: 2560
# (0028, 0030) Pixel Spacing                       DS: [0.0700, 0.0700]
# (0028, 0034) Pixel Aspect Ratio                  IS: [180, 180]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 14
# (0028, 0102) High Bit                            US: 13
# (0028, 0103) Pixel Representation                US: 0
# (0028, 0301) Burned In Annotation                CS: 'NO'
# (0028, 1040) Pixel Intensity Relationship        CS: 'LIN'
# (0028, 1041) Pixel Intensity Relationship Sign   SS: 1
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'US'
# (0028, 1300) Breast Implant Present              CS: 'NO'
# (0028, 1350) Partial View                        CS: ''
# (0028, 1351) Partial View Description            ST: ''
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0032, 000c) Study Priority ID                   CS: ''
# (0032, 1000) Scheduled Study Start Date          DA: ''
# (0032, 1001) Scheduled Study Start Time          TM: ''
# (0032, 1030) Reason for Study                    LO: 'SCREENING'
# (0032, 1032) Requesting Physician                PN: 'Data anonymised^^^^'
# (0032, 1060) Requested Procedure Description     LO: 'Data anonymised'
# (0032, 4000) Study Comments                      LT: 'Data anonymised'
# (0038, 0010) Admission ID                        LO: 'Data anonymised'
# (0038, 0016) Route of Admissions                 LO: ''
# (0038, 0020) Admitting Date                      DA: '19000101'
# (0038, 0021) Admitting Time                      TM: '000000'
# (0038, 0300) Current Patient Location            LO: 'Data anonymised'
# (0040, 0253) Performed Procedure Step ID         SH: 'Data anonymised'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'Screening Mammography'
# (0040, 0275)  Request Attributes Sequence  1 item(s) ----
#    (0040, 0009) Scheduled Procedure Step ID         SH: '0'
#    (0040, 1001) Requested Procedure ID              SH: 'Data anonymised'
#    ---------
# (0040, 0302) Entrance Dose                       US: 0
# (0040, 0314) Half Value Layer                    DS: '0.552'
# (0040, 0316) Organ Dose                          DS: '0.0133'
# (0040, 0318) Organ Exposed                       CS: 'BREAST'
# (0040, 0555)  Acquisition Context Sequence  0 item(s) ----
# (0040, 1003) Requested Procedure Priority        SH: ''
# (0040, 1004) Patient Transport Arrangements      LO: 'Data anonymised'
# (0040, 1010) Names of Intended Recipients of Res PN: 'Data anonymised^^^^'
# (0040, 8302) Entrance Dose in mGy                DS: '4.67'
# (0050, 0004) Calibration Image                   CS: 'NO'
# (0054, 0220)  View Code Sequence  1 item(s) ----
#    (0008, 0100) Code Value                          SH: 'R-10242'
#    (0008, 0102) Coding Scheme Designator            SH: 'SNM3'
#    (0008, 0104) Code Meaning                        LO: 'cranio-caudal'
#    (0054, 0222)  View Modifier Code Sequence  0 item(s) ----
#    ---------
# (2050, 0020) Presentation LUT Shape              CS: 'INVERSE'
# (7fe0, 0010) Pixel Data                          OW: Array of 17039360 elements

# %%
# save bbox coordinates in asingle string
x1 = image_ex.marks[0].boundingBox.x1
y1 = image_ex.marks[0].boundingBox.y1
x2 = image_ex.marks[0].boundingBox.x2
y2 = image_ex.marks[0].boundingBox.y2

bbcoords = f'({x1},{y1},{x2},{y2})'
print(bbcoords)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/ricardo/master_thesis/diffusion-models_master/dataset_analysis/dataset_construction/dataset_initials.ipynb Cell 21 line 2
#       <a href='vscode-notebook-cell://ssh-remote%2Brackmic2/home/ricardo/master_thesis/diffusion-models_master/dataset_analysis/dataset_construction/dataset_initials.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # save bbox coordinates in asingle string
# ----> <a href='vscode-notebook-cell://ssh-remote%2Brackmic2/home/ricardo/master_thesis/diffusion-models_master/dataset_analysis/dataset_construction/dataset_initials.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> x1 = image_ex.marks[0].boundingBox.x1
#       <a href='vscode-notebook-cell://ssh-remote%2Brackmic2/home/ricardo/master_thesis/diffusion-models_master/dataset_analysis/dataset_construction/dataset_initials.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> y1 = image_ex.marks[0].boundingBox.y1
#       <a href='vscode-notebook-cell://ssh-remote%2Brackmic2/home/ricardo/master_thesis/diffusion-models_master/dataset_analysis/dataset_construction/dataset_initials.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> x2 = image_ex.marks[0].boundingBox.x2
#
# IndexError: list index out of range

# %%
lesion = image_ex.dcm.pixel_array[y1:y2, x1:x2]
# show lesion
plt.figure()
plt.imshow(lesion, cmap='gray')# plot bounding box on top of original image
plt.figure(figsize=(10,10))
plt.imshow(image_ex.dcm.pixel_array, cmap='gray')
plt.plot([x1,x2,x2,x1,x1],[y1,y1,y2,y2,y1], 'r-')

# %% [markdown]
# # Construction of the dataset

# %% [markdown]
# ## Functions

# %%
class stats:
    """Class for keeping track of the statistics of the dataset
    """
    def __init__(self, N:int, B:int, M:int, IC:int):
        """Initialize the statistics object

        Args:
            N (int): Normal client status
            B (int): Bening client status
            M (int): Malignant client status
            IC (int): Interval Cancer client status
        """
        self.N = N
        self.M = M
        self.B = B
        self.IC = IC # not present
        self.image_CC = 0
        self.image_MLO = 0
        self.image_R = 0
        self.image_L = 0
        self.subtype = np.zeros(8, dtype=np.int32)

    def __repr__(self):
        """when printing the object, print the following:

        Returns:
            str: description of the statistics
        """
        return \
            f'Stats [N: {self.N}, M {self.M}, B: {self.B}, IC {self.IC},'\
            f'CC: {self.image_CC}, MLO: {self.image_MLO}, '\
            f'R: {self.image_R}, L:{self.image_L}, ' \
            f'Subtype: {np.array2string(self.subtype)} ]'

def update_stats_patient(overall:stats, client):

    # Save the general pathological status of the patient:
    #   M: malignant, N:Normal, CI: Interval Cancer
    # In the API, the label is given in the following order of importance:
    # CI > M > B > N
    if client.status.value == 'Interval Cancer': # not present
        overall.IC += 1
    elif client.status.value == 'Malignant':
        overall.M += 1
    elif client.status.value == 'Benign':
        overall.B += 1
    elif client.status.value == 'Normal':
        overall.N += 1
    return overall

# %%
def check_tag_and_value(json_data:dict, tag:str):
    """returns true if the tag is in the json file and has value

    Args:
        json_data (dict): json object with the data
        tag (str): DICOM tag

    Returns:
        bool: true if the tag is in the json file and has value
    """
    return (tag in json_data) and ('Value' in json_data[tag])

def check_presence(json_data:dict):
    """checks if the json file has the required fields

    Args:
        json_data (dict): jason object with the data

    Returns:
        bool: true if the json file has the required fields
    """
    # criteria for selecting images
    for_pres = json_data['00080068']['Value'][0] == 'FOR PRESENTATION' # only images for presentation
    series_descrip = check_tag_and_value(json_data, '0008103E') # check if the series description (side view or other) is defined and has value
    manufacturer = check_tag_and_value(json_data, '00080070') # check if the manufacturer is defined and has value
    fov_type = check_tag_and_value(json_data, '00191039') # check if the fov_type is defined and has value

    if for_pres and (not fov_type): #and series_descrip and manufacturer: # if all the criteria are met, return True
        return True
    else:
        return False

def json_tag2value(json_data:dict, tag:str):
    """returns the value of the tag in the json file

    Args:
        json_data (dict): json object with the data
        tag (str): DICOM tag

    Returns:
        str: value of the tag or None
    """
    if check_tag_and_value(json_data, tag):
        return json_data[tag]['Value'][0]
    else:
        return None

# %% [markdown]
# ## Dataset metadata

# %%
#define the path to the dataset
reading_path = '/mnt/mia_images/breast/omi-db/image_db/sharing/omi-db/'
# db = omidb.DB(reading_path, clients=['demd100018', 'demd128247', 'demd843','demd94678'])
db = omidb.DB(reading_path)

# %% [markdown]
# NBSS data is **client level** information stored in a dictionary, containing:
# - The client id
# - The episodes id (one key per episode)
# - The classification veredict ()

# %% [markdown]
# ### Keeping some visual help

# %%
# create dataframe storing path, presentation type, side, manufacturer, view
df = None

# Initialize the statistics object
overall = stats(0, 0, 0, 0)
for client in tqdm(db, total=len(db.clients)):          # client level
    overall = update_stats_patient(overall, client) # extract the client status for statistics
    nbss_data = db._nbss(client.id) # store nbss data of the client
    # print('=====================================')
    # print(f'Client: {client.id}')
    for episode in client.episodes:                     # episode level
        if episode.studies is not None: # only if the episode has studies
            # print('---------------------------------')
            # print(f'Episode {episode.id}')
            # print('---------------------------------')
            # Episodes may have multiple studies
            # episode_data = nbss_data.get(episode.id, None) # get the nbss data of the episode
            # for key, value in episode_data.items():
            #     if key in ['BIOPSYWIDE', 'SURGERY', 'SCREENING', 'ASSESSMENT']: # for each main information type
            #         for sides_keys, sides_values in value.items(): # inside each of this main information type
            #             if sides_keys=='R' or sides_keys=='L': # if the sides are well defined
            #                 side = sides_keys # define the side
            #                 print(side)
            for study in episode.studies:
                # print('//////////////')
                # print(f'Study {study.event_type}')
                for series in study.series:
                    # print('*************')
                    # print(f'Series {series}')
                    for image in series.images:
                        # print('##############')
                        # add information of current image to dataframe using concat
                        with open(image.json_path, 'r') as f: # open the json file
                            json_data = json.load(f)
                        df = pd.concat(
                            [df, pd.DataFrame(
                            {
                                'client_id': client.id,
                                'episode_id': episode.id,
                                'study_id': study.id,
                                'series_id': series.id,
                                'image_id': image.id,
                                'path': image.dcm_path,
                                'json_path': image.json_path,
                                'presentation': json_data['00080068']['Value'][0],
                                'side': json_data['0008103E']['Value'][0].split(' ')[0],
                                'manufacturer': json_data['00080070']['Value'][0],
                                'view': json_data['0008103E']['Value'][0].split(' ')[1],
                                'magnification': json_data['00191039']['Value'][0] if '00191039' in json_data else None,
                            }, index=[0])], axis=0)
# save the dataframe
df.to_csv('metadata.csv', index=False)
# Out:
# 100%|██████████| 4/4 [00:00<00:00,  5.53it/s]

# %%
# open dataframe
df = pd.read_csv('metadata.csv')
# filter by presentation
df = df[df['presentation']=='FOR PRESENTATION']
df.json_path[0]
# Out:
# '/mnt/mia_images/breast/omi-db/image_db/sharing/omi-db/data/demd128247/1.2.826.0.1.3680043.9.3218.1.1.242302667.45008.1546430561995.2.0/1.2.826.0.1.3680043.9.3218.1.1.242302667.45008.1546430561995.5.0.dcm.json'

# %%
# open dataframe
df = pd.read_csv('metadata.csv')
# filter by presentation
df = df[df['presentation']=='FOR PRESENTATION']
# filter by side
df = df[df['view']=='LM']
for path in df.path:
    # open the dicom file
    print(path)
    dcm = pydicom.dcmread(path)
    # get the image
    image = dcm.pixel_array
    # plot the image
    plt.figure()
    plt.imshow(image, cmap='gray')
# Out:
# /mnt/mia_images/breast/omi-db/image_db/sharing/omi-db/images/demd128247/1.2.826.0.1.3680043.9.3218.1.1.242302667.4500.1546430561995.53.0/1.2.826.0.1.3680043.9.3218.1.1.242302667.4500.1546430561995.63.0.dcm
# /mnt/mia_images/breast/omi-db/image_db/sharing/omi-db/images/demd128247/1.2.826.0.1.3680043.9.3218.1.1.242302667.4500.1546430561995.53.0/1.2.826.0.1.3680043.9.3218.1.1.242302667.4500.1546430561995.66.0.dcm

# %% [markdown]
# ### CSV of *for presentation* images

# %%
# create dataframe storing path, presentation type, side, manufacturer, view
df = None
empty_json = 0

# read dicom tags yaml
with open('metadata/dicom_tags.yaml', 'r') as file:
    tags = yaml.load(file, Loader=yaml.FullLoader)

# Initialize the statistics object
overall = stats(0, 0, 0, 0)
for client in tqdm(db, total=len(db.clients)):          #@ client level
    overall = update_stats_patient(overall, client) # extract the client status for statistics
    nbss_data = db._nbss(client.id) # store nbss data of the client
    for episode in client.episodes:                     #@ episode level
        if episode.studies is not None: # only if the episode has studies
            for study in episode.studies:               #@ study level
                for series in study.series:             #@ series level
                    for image in series.images:         #@ image level
                        with open(image.json_path, 'r') as file: # open the image json file
                            if file.read() != '': # check the file is not empty
                                file.seek(0) # go back to the beginning of the file
                                json_data = json.load(file)
                            else:
                                empty_json += 1
                        # check if the json file has the relevant information
                        if check_presence(json_data): # if the image is for presentation
                            # object oriented information storage
                            df_sub = pd.DataFrame(
                                {
                                    'client_id': client.id,
                                    'episode_id': episode.id,
                                    'study_id': study.id,
                                    'series_id': series.id,
                                    'image_id': image.id,
                                    'path': image.dcm_path,
                                    'json_path': image.json_path,
                                    'client_status': client.status.value,
                                }, index=[0])
                            # go through the tags and save the json-contained information
                            for tag in tags:
                                df_sub = pd.concat([df_sub, pd.DataFrame({tag: json_tag2value(json_data, tags[tag])}, index=[0])], axis=1)
                            # concat in general df
                            df = pd.concat(
                                [df, df_sub], axis=0)                        

# save the dataframe
df.to_csv('metadata/metadata_FP.csv', index=False)

# print the statistics
subclients_num =  len(df['client_id'].unique())
print(f'Number of valid clients: {subclients_num}')
print(f'Images with no valid json file: {empty_json}')
# Out:
#  24%|██▍       | 1454/6000 [09:09<28:37,  2.65it/s]
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1223254/3938743672.py", line -1, in <module>
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %% [markdown]
# The whole dataset size.
