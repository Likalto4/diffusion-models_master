# %%
#Add repo path to the system path
from pathlib import Path
import os, sys
repo_path= Path.cwd().resolve()
while '.gitignore' not in os.listdir(repo_path): # while not in the root of the repo
    repo_path = repo_path.parent #go up one level
sys.path.insert(0,str(repo_path)) if str(repo_path) not in sys.path else None

import omidb
from pathlib import Path
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import json
import pydicom
import yaml
from pydicom.pixel_data_handlers.util import apply_voi_lut

# %% [markdown]
# # Dataset analysis
#
#      The dataset folder is being mounted to padel from mia server.

# %% [markdown]
# To start we want to create a db object that contains all the clients found in the omi-db path. <br>
# The second step is to create a list of all the clients that are in the omi-db path. <br>

# %%
#define the path to the dataset
reading_path = '/mnt/mia_images/breast/omi-db/image_db/sharing/omi-db/'
#db = omidb.DB(reading_path, clients=['demd111011'])
db = omidb.DB(reading_path)
#save clients in a list
clients = [client for client in db]
#The number of clients/petients
len(clients)
# Out:
# 6000

# %% [markdown]
# ## Structure of the OMI-DB dataset object

# %% [markdown]
# A <ins> **client** </ins>. represents a patient and can have one or more episodes. <br>
#
# - The client object gives information about the client such as:
#     - The client id
#     - A list of episodes
#     - The site (hospital) name
#     - The client's status (benign, malignant, normal, interval cancer)
#
# Let's take a client exmaple and analyze it:

# %%
client_num = 0
#get a client
client_ex = clients[client_num]
print(f'The client id is: {client_ex.id}')
print(f'The client number of episodes is: {len(client_ex.episodes)}')
print(f'The name of the site is: {client_ex.site.value}')
print(f'The client status is: {client_ex.status.value}')
# Out:
# The client id is: demd4401
# The client number of episodes is: 5
# The name of the site is: jarv
# The client status is: Malignant

# %% [markdown]
# We can also access the nbss data using the client id.
# This contains redudant information as:
# - client id
# - client status,
#
# but also new information of the lower level of the dataset.

# %%
nbss_data = db._nbss(client_ex.id)
keys = list(nbss_data.keys())
print(keys)
nbss_data
# nbss_data[keys[3]]
# Out:
# ['9972', '9993', 'ClientID', '9978', '9999', '9988', 'Classification']
# {'9972': {'EpisodeIsClosed': 'Y',
#   'EpisodeType': 'R',
#   'PatientAge': 66,
#   'BIOPSYWIDE': {'diagnosticsetoutcome': 'W+',
#    'Opinion': None,
#    'left_opinion': 'Malignant',
#    'L': {'1': {'DiagnosticSetOutcome': 'W+',
#      'Opinion': 'B5',
#      'MalignancyType': 'b',
#      'HormonePRScore': None,
#      'CalcificationOnSpecimen': None,
#      'InvasivePresent': 'N',
#      'LocalisationType': 'U',
#      'left_opinion': 'Malignant',
#      'SpecimenType': None,
#      'Location': None,
#      'InsituPresent': None,
#      'InSituComponents': None,
#      'BenignLesions': None,
#      'HormoneERStatus': None,
#      'HormoneERScore': None,
#      'SideCode': 'L',
#      'DiseaseGrade': None,
#      'HormonePRStatus': None,
#      'DcisGrade': None,
#      'HER2ReceptorScore': None,
#      'right_opinion': None,
#      'LymphNode': 'N',
#      'InvasiveType': None,
#      'HistologicalCalcification': 'A',
#      'DatePerformed': '1995-09-15',
#      'NeedleSpecimenType': 'WBN',
#      'HER2ReceptorStatus': None,
#      'InvasiveTypeOther': None,
#      'EpithelialProliferation': None,
#      'InvasiveComponents': None}},
#    'right_opinion': None,
#    'dateperformed': '1995-09-15'},
#   'AccessionID': 'CRY3698410494, CRY4162521903, CRY2013883348, CRY2611170056, CRY592366744, CRY3200920341, CRY3151695362',
#   'EpisodeClosedDate': '1995-11-28',
#   'EpisodeOpenedDate': '1995-06-27',
#   'ASSESSMENT': {'diagnosticsetoutcome': 'A+',
#    'Opinion': None,
#    'left_opinion': 'Malignant',
#    'L': {'1': {'DiagnosticSetOutcome': 'A+',
#      'UssMass': 'I',
#      'UssSizeMm': None,
#      'MammoAttributes': None,
#      'RightAxillaOpinion': None,
#      'MammoCalcification': 'N',
#      'UssOpinion': 'U5',
#      'SideCode': 'L',
#      'MammoSizeMm90': None,
#      'UssAttributes': None,
#      'MammoOpinion': 'R4',
#      'DatePerformed': '1995-09-15',
#      'MammoMass': 'I',
#      'MammoSizeMm': '12',
#      'LeftAxillaOpinion': 'N',
#      'action': 'For WBN',
#      'MammoFocus': 'U',
#      'UssLymphNode': 'N'}},
#    'right_opinion': None,
#    'dateperformed': '1995-09-15'},
#   'SURGERY': {'diagnosticsetoutcome': 'H+',
#    'Opinion': None,
#    'left_opinion': 'Malignant',
#    'L': {'1': {'CalcificationsOnSpecimen': None,
#      'WholeSizeOfTumour': '20.0',
#      'Microinvasion': 'MNP',
#      'Opinion': 'H5',
#      'DiagnosticProcedure': None,
#      'NationalTrial': None,
#      'HormonePRScore': '6',
#      'LocalTrialCode': None,
#      'DiseaseExtent': 'DEL',
#      'TherapeuticProcedures': 'SD',
#      'TreatmentProcedure': 'WLE',
#      'BenignLesions': None,
#      'HormoneERScore': '8',
#      'SizeDuctalOnly': None,
#      'AxillaryNodesPositive': None,
#      'right_opinion': None,
#      'AxillarySpecimenType': None,
#      'AxillaryMetsType': None,
#      'ExcisionMargins': 'ED',
#      'AxillaryNodesNumberPositive': '0',
#      'BiopsySpecimenType': 'WX',
#      'InvasiveComponents': None,
#      'DcisGrowthPatterns': 'GC GO',
#      'ReconstructiveProcedure': None,
#      'NonsurgicalTreatments': 'EB RB',
#      'Chemotherapy': 'N',
#      'left_opinion': 'Malignant',
#      'CancerOnKC62': 'N',
#      'InSituComponents': 'NID',
#      'HormoneERStatus': 'RP',
#      'Event': 'PTR',
#      'DiseaseGrade': 'G3',
#      'DcisGrade': 'NDH',
#      'HER2ReceptorScore': None,
#      'HormonePRStatus': 'RP',
#      'InvasiveType': 'IN',
#      'HistologicalCalcification': 'A',
#      'DatePerformed': '1995-10-24',
#      'HER2ReceptorStatus': 'RN',
#      'ExcisionMarginDistance': '1.0',
#      'EpithelialProliferation': None,
#      'InvasiveTypeOther': None}},
#    'right_opinion': None,
#    'dateperformed': '1995-10-24'},
#   'CLINICAL': {'diagnosticsetoutcome': 'Aabn',
#    'Opinion': None,
#    'left_opinion': 'Uncertain',
#    'L': {'1': {'DiscreteMass': 'N',
#      'SizeMm': None,
#      'Opinion': 'P3',
#      'Nodularity': 'N',
#      'SkinChanges': 'N',
#      'NippleDischarge': 'N',
#      'right_opinion': 'Normal',
#      'DatePerformed': '1995-09-15',
#      'NippleChanges': 'N',
#      'left_opinion': 'Uncertain',
#      'RightAxillaOpinion': None,
#      'LeftAxillaOpinion': 'N'}},
#    'right_opinion': 'Normal',
#    'dateperformed': '1995-09-15'},
#   'EpisodeAction': 'FP',
#   'LESION': {'L': {'1': {'LesionNotes': None,
#      'LesionDescription': 'Mass',
#      'LesionPosition': 'LD4',
#      'CystAspirated': 'N'}}},
#   'StudyList': '1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.33.0',
#   'SCREENING': {'diagnosticsetoutcome': None,
#    'Opinion': None,
#    'left_opinion': 'Uncertain',
#    'R': {'SizeMm': None,
#     'FilmReader1Opinion': 'N',
#     'FilmRecommendedActions': 'RC RC RC',
#     'FilmReader1RecAction': 'RC',
#     'NumberOfRepeats': '1',
#     'Opinion': 'RN',
#     'FilmReaderOpinions': 'N',
#     'EquipmentMakeModel': 'Hologic Selenia',
#     'FinalAction': 'RC',
#     'Microcalcification': None,
#     'DateTaken': '1995-08-25',
#     'FilmReader3RecAction': 'RC',
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'RC',
#     'EquipmentUsed': '15',
#     'FilmReader2Opinion': 'N',
#     'SideCode': 'R',
#     'RepeatReason': 'E10',
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD44 RD35 RD58',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': 'N'},
#    'L': {'SizeMm': None,
#     'FilmReader1Opinion': 'A',
#     'FilmRecommendedActions': 'RC RC RC',
#     'FilmReader1RecAction': 'RC',
#     'NumberOfRepeats': None,
#     'Opinion': 'RU',
#     'FilmReaderOpinions': 'A',
#     'EquipmentMakeModel': 'Hologic Selenia',
#     'FinalAction': 'RC',
#     'Microcalcification': None,
#     'DateTaken': '1995-08-25',
#     'FilmReader3RecAction': 'RC',
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'RC',
#     'EquipmentUsed': '15',
#     'FilmReader2Opinion': 'A',
#     'SideCode': 'L',
#     'RepeatReason': None,
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD44 RD35 RD58',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': 'A'},
#    'right_opinion': 'Normal',
#    'dateperformed': None}},
#  '9993': {'EpisodeOpenedDate': '1986-03-10',
#   'EpisodeIsClosed': 'Y',
#   'EpisodeType': 'R',
#   'PatientAge': 66,
#   'AccessionID': '',
#   'EpisodeClosedDate': '1986-05-01',
#   'EpisodeAction': 'RR',
#   'StudyList': '',
#   'SCREENING': {'diagnosticsetoutcome': None,
#    'Opinion': None,
#    'left_opinion': 'Normal',
#    'R': {'SizeMm': None,
#     'FilmReader1Opinion': None,
#     'FilmRecommendedActions': 'RR RR',
#     'FilmReader1RecAction': 'RR',
#     'NumberOfRepeats': None,
#     'Opinion': 'RN',
#     'FilmReaderOpinions': None,
#     'EquipmentMakeModel': None,
#     'FinalAction': 'RR',
#     'Microcalcification': None,
#     'DateTaken': '1986-04-18',
#     'FilmReader3RecAction': None,
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'RR',
#     'EquipmentUsed': None,
#     'FilmReader2Opinion': None,
#     'SideCode': 'R',
#     'RepeatReason': None,
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD6 RD24',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'L': {'SizeMm': None,
#     'FilmReader1Opinion': None,
#     'FilmRecommendedActions': 'RR RR',
#     'FilmReader1RecAction': 'RR',
#     'NumberOfRepeats': None,
#     'Opinion': 'RN',
#     'FilmReaderOpinions': None,
#     'EquipmentMakeModel': None,
#     'FinalAction': 'RR',
#     'Microcalcification': None,
#     'DateTaken': '1986-04-18',
#     'FilmReader3RecAction': None,
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'RR',
#     'EquipmentUsed': None,
#     'FilmReader2Opinion': None,
#     'SideCode': 'L',
#     'RepeatReason': None,
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD6 RD24',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'right_opinion': 'Normal',
#    'dateperformed': None}},
#  'ClientID': 'demd4401',
#  '9978': {'EpisodeOpenedDate': '1992-07-07',
#   'EpisodeIsClosed': 'Y',
#   'EpisodeType': 'R',
#   'PatientAge': 66,
#   'AccessionID': 'CRY2246931139, CRY561933650',
#   'EpisodeClosedDate': '1992-11-03',
#   'EpisodeAction': 'RR',
#   'StudyList': '1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.27.0,1.2.826.0.1.3680043.9.3218.1.1.167619013.21195.1511996139973.2.0',
#   'SCREENING': {'diagnosticsetoutcome': None,
#    'Opinion': None,
#    'left_opinion': 'Normal',
#    'R': {'SizeMm': None,
#     'FilmReader1Opinion': None,
#     'FilmRecommendedActions': 'TR TR TR',
#     'FilmReader1RecAction': 'TR',
#     'NumberOfRepeats': None,
#     'Opinion': 'RN',
#     'FilmReaderOpinions': None,
#     'EquipmentMakeModel': 'Hologic Selenia',
#     'FinalAction': 'TR',
#     'Microcalcification': None,
#     'DateTaken': '1992-09-16',
#     'FilmReader3RecAction': 'TR',
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'TR',
#     'EquipmentUsed': '19',
#     'FilmReader2Opinion': None,
#     'SideCode': 'R',
#     'RepeatReason': None,
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD24 RD47 RD5',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'L': {'SizeMm': None,
#     'FilmReader1Opinion': None,
#     'FilmRecommendedActions': 'TR TR TR',
#     'FilmReader1RecAction': 'TR',
#     'NumberOfRepeats': None,
#     'Opinion': 'RO',
#     'FilmReaderOpinions': None,
#     'EquipmentMakeModel': 'Hologic Selenia',
#     'FinalAction': 'TR',
#     'Microcalcification': None,
#     'DateTaken': '1992-09-16',
#     'FilmReader3RecAction': 'TR',
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'TR',
#     'EquipmentUsed': '19',
#     'FilmReader2Opinion': None,
#     'SideCode': 'L',
#     'RepeatReason': 'R7',
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD24 RD47 RD5',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'right_opinion': 'Normal',
#    'dateperformed': None}},
#  '9999': {'EpisodeOpenedDate': '1983-08-02',
#   'EpisodeIsClosed': 'Y',
#   'EpisodeType': 'F',
#   'PatientAge': 66,
#   'AccessionID': '',
#   'EpisodeClosedDate': '1983-09-26',
#   'EpisodeAction': 'RR',
#   'StudyList': '',
#   'SCREENING': {'diagnosticsetoutcome': None,
#    'Opinion': None,
#    'left_opinion': 'Normal',
#    'R': {'SizeMm': None,
#     'FilmReader1Opinion': None,
#     'FilmRecommendedActions': 'RR',
#     'FilmReader1RecAction': 'RR',
#     'NumberOfRepeats': None,
#     'Opinion': 'RN',
#     'FilmReaderOpinions': None,
#     'EquipmentMakeModel': None,
#     'FinalAction': 'RR',
#     'Microcalcification': None,
#     'DateTaken': '1983-08-31',
#     'FilmReader3RecAction': None,
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': None,
#     'EquipmentUsed': None,
#     'FilmReader2Opinion': None,
#     'SideCode': 'R',
#     'RepeatReason': None,
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD12',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'L': {'SizeMm': None,
#     'FilmReader1Opinion': None,
#     'FilmRecommendedActions': 'RR',
#     'FilmReader1RecAction': 'RR',
#     'NumberOfRepeats': None,
#     'Opinion': 'RN',
#     'FilmReaderOpinions': None,
#     'EquipmentMakeModel': None,
#     'FinalAction': 'RR',
#     'Microcalcification': None,
#     'DateTaken': '1983-08-31',
#     'FilmReader3RecAction': None,
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': None,
#     'EquipmentUsed': None,
#     'FilmReader2Opinion': None,
#     'SideCode': 'L',
#     'RepeatReason': None,
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD12',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'right_opinion': 'Normal',
#    'dateperformed': None}},
#  '9988': {'EpisodeOpenedDate': '1989-02-21',
#   'EpisodeIsClosed': 'Y',
#   'EpisodeType': 'R',
#   'PatientAge': 66,
#   'AccessionID': '',
#   'EpisodeClosedDate': '1989-05-10',
#   'EpisodeAction': 'RR',
#   'StudyList': '',
#   'SCREENING': {'diagnosticsetoutcome': None,
#    'Opinion': None,
#    'left_opinion': 'Normal',
#    'R': {'SizeMm': None,
#     'FilmReader1Opinion': 'N',
#     'FilmRecommendedActions': 'RR RR',
#     'FilmReader1RecAction': 'RR',
#     'NumberOfRepeats': None,
#     'Opinion': 'RN',
#     'FilmReaderOpinions': 'N',
#     'EquipmentMakeModel': 'Hologic Selenia',
#     'FinalAction': 'RR',
#     'Microcalcification': None,
#     'DateTaken': '1989-05-02',
#     'FilmReader3RecAction': None,
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'RR',
#     'EquipmentUsed': '16',
#     'FilmReader2Opinion': 'N',
#     'SideCode': 'R',
#     'RepeatReason': None,
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD40 RD64',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'L': {'SizeMm': None,
#     'FilmReader1Opinion': 'N',
#     'FilmRecommendedActions': 'RR RR',
#     'FilmReader1RecAction': 'RR',
#     'NumberOfRepeats': None,
#     'Opinion': 'RN',
#     'FilmReaderOpinions': 'N',
#     'EquipmentMakeModel': 'Hologic Selenia',
#     'FinalAction': 'RR',
#     'Microcalcification': None,
#     'DateTaken': '1989-05-02',
#     'FilmReader3RecAction': None,
#     'FilmReader4RecAction': None,
#     'FilmReader2RecAction': 'RR',
#     'EquipmentUsed': '16',
#     'FilmReader2Opinion': 'N',
#     'SideCode': 'L',
#     'RepeatReason': None,
#     'FilmReader4Opinion': None,
#     'MicrocalcWithMass': None,
#     'Mass': None,
#     'FilmReader5Opinion': None,
#     'FilmReaders': 'RD40 RD64',
#     'FilmReader5RecAction': None,
#     'FilmReader3Opinion': None},
#    'right_opinion': 'Normal',
#    'dateperformed': None}},
#  'Classification': 'M'}

# %% [markdown]
# The next interesting object is the episode <ins> **object** </ins>. <br>
# Episodes contain a set of medical procedures or events associated with the treatment or diagnosis. <br>
# - The episode object contains:
#     - The episode id (unique for within client)
#     - Events object: a set of medical procedures or events associated wiith the episode
#     - Studies list: studies are collections of screening and diagnostic images

# %%
episode_num = 0
#Get the first episode of the client as example
episode_ex = client_ex.episodes[episode_num]
#get id of the episode
print(f'The episode id is: {episode_ex.id}')
print(f'The number of studies is: {len(episode_ex.studies)}') if episode_ex.studies else print('No studies')
print(f'The episode type is: {episode_ex.type.value}')
print(f'The episode action is: {episode_ex.action.value}') if episode_ex.action else print('No action')
print(f'The episode opened date is: {episode_ex.opened_date}')
print(f'The episode closed date is: {episode_ex.closed_date}')
print(f'is the episode closed?: {episode_ex.is_closed}')
print(f'number of lesions in the episode: {len(episode_ex.lesions)}') if episode_ex.lesions else print('No lesions')

# Addiitioanl properties can be given back:
print(f'The episode has benign opinions?: {episode_ex.has_benign_opinions}')
print(f'The episode has malignant opinions?: {episode_ex.has_malignant_opinions}')
#print seperator
print('-----------------------------')
# Get the events object, it shows all the events that happened in the episode
events_ex = episode_ex.events
print(f'All the events in the episode: \n{events_ex}')
print(events_ex)
# Out:
# The episode id is: 9972
# The number of studies is: 1
# The episode type is: Routine Recall
# The episode action is: Follow-up (Post-treatment)
# The episode opened date is: 1995-06-27
# The episode closed date is: 1995-11-28
# is the episode closed?: True
# No lesions
# The episode has benign opinions?: False
# The episode has malignant opinions?: True
# -----------------------------
# All the events in the episode:
# Events(screening=[Screening(left_opinion=<SideOpinion.OU: 'Uncertain'>, right_opinion=<SideOpinion.ON: 'Normal'>, dates=[datetime.date(1995, 8, 25)], left=BreastScreeningData(date=datetime.date(1995, 8, 25), equipment_make_model='Hologic Selenia', opinion=<Opinion.RU: 'R Uncertain'>), right=BreastScreeningData(date=datetime.date(1995, 8, 25), equipment_make_model='Hologic Selenia', opinion=<Opinion.RN: 'R Normal'>))], assessment=BaseEvent(left_opinion=<SideOpinion.OM: 'Malignant'>, right_opinion=None, dates=[datetime.date(1995, 9, 15)]), clinical=BaseEvent(left_opinion=<SideOpinion.OU: 'Uncertain'>, right_opinion=<SideOpinion.ON: 'Normal'>, dates=[datetime.date(1995, 9, 15)]), biopsy_wide=BaseEvent(left_opinion=<SideOpinion.OM: 'Malignant'>, right_opinion=None, dates=[datetime.date(1995, 9, 15)]), biopsy_fine=None, surgery=BaseEvent(left_opinion=<SideOpinion.OM: 'Malignant'>, right_opinion=None, dates=[datetime.date(1995, 10, 24)]))
# Events(screening=[Screening(left_opinion=<SideOpinion.OU: 'Uncertain'>, right_opinion=<SideOpinion.ON: 'Normal'>, dates=[datetime.date(1995, 8, 25)], left=BreastScreeningData(date=datetime.date(1995, 8, 25), equipment_make_model='Hologic Selenia', opinion=<Opinion.RU: 'R Uncertain'>), right=BreastScreeningData(date=datetime.date(1995, 8, 25), equipment_make_model='Hologic Selenia', opinion=<Opinion.RN: 'R Normal'>))], assessment=BaseEvent(left_opinion=<SideOpinion.OM: 'Malignant'>, right_opinion=None, dates=[datetime.date(1995, 9, 15)]), clinical=BaseEvent(left_opinion=<SideOpinion.OU: 'Uncertain'>, right_opinion=<SideOpinion.ON: 'Normal'>, dates=[datetime.date(1995, 9, 15)]), biopsy_wide=BaseEvent(left_opinion=<SideOpinion.OM: 'Malignant'>, right_opinion=None, dates=[datetime.date(1995, 9, 15)]), biopsy_fine=None, surgery=BaseEvent(left_opinion=<SideOpinion.OM: 'Malignant'>, right_opinion=None, dates=[datetime.date(1995, 10, 24)]))

# %%
# nbss data of the same episode
episode_data = nbss_data.get(episode_ex.id, {})
for key, value in episode_data.items():
    print(f'{key}: {value}')
# Out:
# EpisodeIsClosed: Y
# EpisodeType: R
# PatientAge: 66
# BIOPSYWIDE: {'diagnosticsetoutcome': 'W+', 'Opinion': None, 'left_opinion': 'Malignant', 'L': {'1': {'DiagnosticSetOutcome': 'W+', 'Opinion': 'B5', 'MalignancyType': 'b', 'HormonePRScore': None, 'CalcificationOnSpecimen': None, 'InvasivePresent': 'N', 'LocalisationType': 'U', 'left_opinion': 'Malignant', 'SpecimenType': None, 'Location': None, 'InsituPresent': None, 'InSituComponents': None, 'BenignLesions': None, 'HormoneERStatus': None, 'HormoneERScore': None, 'SideCode': 'L', 'DiseaseGrade': None, 'HormonePRStatus': None, 'DcisGrade': None, 'HER2ReceptorScore': None, 'right_opinion': None, 'LymphNode': 'N', 'InvasiveType': None, 'HistologicalCalcification': 'A', 'DatePerformed': '1995-09-15', 'NeedleSpecimenType': 'WBN', 'HER2ReceptorStatus': None, 'InvasiveTypeOther': None, 'EpithelialProliferation': None, 'InvasiveComponents': None}}, 'right_opinion': None, 'dateperformed': '1995-09-15'}
# AccessionID: CRY3698410494, CRY4162521903, CRY2013883348, CRY2611170056, CRY592366744, CRY3200920341, CRY3151695362
# EpisodeClosedDate: 1995-11-28
# EpisodeOpenedDate: 1995-06-27
# ASSESSMENT: {'diagnosticsetoutcome': 'A+', 'Opinion': None, 'left_opinion': 'Malignant', 'L': {'1': {'DiagnosticSetOutcome': 'A+', 'UssMass': 'I', 'UssSizeMm': None, 'MammoAttributes': None, 'RightAxillaOpinion': None, 'MammoCalcification': 'N', 'UssOpinion': 'U5', 'SideCode': 'L', 'MammoSizeMm90': None, 'UssAttributes': None, 'MammoOpinion': 'R4', 'DatePerformed': '1995-09-15', 'MammoMass': 'I', 'MammoSizeMm': '12', 'LeftAxillaOpinion': 'N', 'action': 'For WBN', 'MammoFocus': 'U', 'UssLymphNode': 'N'}}, 'right_opinion': None, 'dateperformed': '1995-09-15'}
# SURGERY: {'diagnosticsetoutcome': 'H+', 'Opinion': None, 'left_opinion': 'Malignant', 'L': {'1': {'CalcificationsOnSpecimen': None, 'WholeSizeOfTumour': '20.0', 'Microinvasion': 'MNP', 'Opinion': 'H5', 'DiagnosticProcedure': None, 'NationalTrial': None, 'HormonePRScore': '6', 'LocalTrialCode': None, 'DiseaseExtent': 'DEL', 'TherapeuticProcedures': 'SD', 'TreatmentProcedure': 'WLE', 'BenignLesions': None, 'HormoneERScore': '8', 'SizeDuctalOnly': None, 'AxillaryNodesPositive': None, 'right_opinion': None, 'AxillarySpecimenType': None, 'AxillaryMetsType': None, 'ExcisionMargins': 'ED', 'AxillaryNodesNumberPositive': '0', 'BiopsySpecimenType': 'WX', 'InvasiveComponents': None, 'DcisGrowthPatterns': 'GC GO', 'ReconstructiveProcedure': None, 'NonsurgicalTreatments': 'EB RB', 'Chemotherapy': 'N', 'left_opinion': 'Malignant', 'CancerOnKC62': 'N', 'InSituComponents': 'NID', 'HormoneERStatus': 'RP', 'Event': 'PTR', 'DiseaseGrade': 'G3', 'DcisGrade': 'NDH', 'HER2ReceptorScore': None, 'HormonePRStatus': 'RP', 'InvasiveType': 'IN', 'HistologicalCalcification': 'A', 'DatePerformed': '1995-10-24', 'HER2ReceptorStatus': 'RN', 'ExcisionMarginDistance': '1.0', 'EpithelialProliferation': None, 'InvasiveTypeOther': None}}, 'right_opinion': None, 'dateperformed': '1995-10-24'}
# CLINICAL: {'diagnosticsetoutcome': 'Aabn', 'Opinion': None, 'left_opinion': 'Uncertain', 'L': {'1': {'DiscreteMass': 'N', 'SizeMm': None, 'Opinion': 'P3', 'Nodularity': 'N', 'SkinChanges': 'N', 'NippleDischarge': 'N', 'right_opinion': 'Normal', 'DatePerformed': '1995-09-15', 'NippleChanges': 'N', 'left_opinion': 'Uncertain', 'RightAxillaOpinion': None, 'LeftAxillaOpinion': 'N'}}, 'right_opinion': 'Normal', 'dateperformed': '1995-09-15'}
# EpisodeAction: FP
# LESION: {'L': {'1': {'LesionNotes': None, 'LesionDescription': 'Mass', 'LesionPosition': 'LD4', 'CystAspirated': 'N'}}}
# StudyList: 1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.33.0
# SCREENING: {'diagnosticsetoutcome': None, 'Opinion': None, 'left_opinion': 'Uncertain', 'R': {'SizeMm': None, 'FilmReader1Opinion': 'N', 'FilmRecommendedActions': 'RC RC RC', 'FilmReader1RecAction': 'RC', 'NumberOfRepeats': '1', 'Opinion': 'RN', 'FilmReaderOpinions': 'N', 'EquipmentMakeModel': 'Hologic Selenia', 'FinalAction': 'RC', 'Microcalcification': None, 'DateTaken': '1995-08-25', 'FilmReader3RecAction': 'RC', 'FilmReader4RecAction': None, 'FilmReader2RecAction': 'RC', 'EquipmentUsed': '15', 'FilmReader2Opinion': 'N', 'SideCode': 'R', 'RepeatReason': 'E10', 'FilmReader4Opinion': None, 'MicrocalcWithMass': None, 'Mass': None, 'FilmReader5Opinion': None, 'FilmReaders': 'RD44 RD35 RD58', 'FilmReader5RecAction': None, 'FilmReader3Opinion': 'N'}, 'L': {'SizeMm': None, 'FilmReader1Opinion': 'A', 'FilmRecommendedActions': 'RC RC RC', 'FilmReader1RecAction': 'RC', 'NumberOfRepeats': None, 'Opinion': 'RU', 'FilmReaderOpinions': 'A', 'EquipmentMakeModel': 'Hologic Selenia', 'FinalAction': 'RC', 'Microcalcification': None, 'DateTaken': '1995-08-25', 'FilmReader3RecAction': 'RC', 'FilmReader4RecAction': None, 'FilmReader2RecAction': 'RC', 'EquipmentUsed': '15', 'FilmReader2Opinion': 'A', 'SideCode': 'L', 'RepeatReason': None, 'FilmReader4Opinion': None, 'MicrocalcWithMass': None, 'Mass': None, 'FilmReader5Opinion': None, 'FilmReaders': 'RD44 RD35 RD58', 'FilmReader5RecAction': None, 'FilmReader3Opinion': 'A'}, 'right_opinion': 'Normal', 'dateperformed': None}

# %% [markdown]
# The next structures are <ins> **events** </ins> and <ins> **studies** </ins>. <br>
# Studies are imaging examinations made out of <ins>series</ins>. Each serie contains a set of <ins> **images** </ins>. <br>
#
#     Note that not all episodes may have studies!!
# This is important to consider, as we care about the episodes that have images (therefore, studies). <br>

# %%
# Get the first study of the episode as example
study_num = 0
if episode_ex.studies:
    study_ex = episode_ex.studies[study_num]
    print(f'The study id is: {study_ex.id}')
    print(f'The number of series is: {len(study_ex.series)}')
    print(f'The event type(s) is: {study_ex.event_type}')
    print(f'The study date is: {study_ex.date}')
    
else:
    print('No studies')
# Out:
# The study id is: 1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.33.0
# The number of series is: 10
# The event type(s) is: [<Event.screening: 'screening'>]
# The study date is: 1995-08-25

# %% [markdown]
# Series are the next and final subsrtucture of the dataset. <br>
# It is a <ins> **collection of images** </ins> taken during one examination by one modality, for a given position of the patient in the acquisition device. <br>
# In full-field digital mammography, each image is usually associated with one series. <br>
# - The series object contains:
#     - The series id
#     - The list of images

# %%
for series_num in range(0,len(study_ex.series)):
    
    # Get the first series of the study as example
    series_ex = study_ex.series[series_num]
    print(f'The series id is: {series_ex.id}')
    print(f'The number of images is: {series_ex.num_images}')
    #All images in the series can be plotted using
    plt.figure(figsize=(10,10))
    series_ex.plot()
    plt.title(f'Series {series_ex.id}')

    print(f'The list of marks in the image is: {series_ex.images[0].marks}')
# Out:
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.53.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.42.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.38.0
# The number of images is: 1
# The list of marks in the image is: [Mark(id='9662', lesion_id='1', boundingBox=BoundingBox(x1=86, y1=1921, x2=295, y2=2113), conspicuity=<Conspicuity.obvious: 'Obvious'>, architectural_distortion=None, dystrophic_calcification=None, fat_necrosis=None, focal_asymmetry=None, mass=True, suspicious_calcifications=None, milk_of_calcium=None, other_benign_cluster=None, plasma_cell_mastitis=None, benign_skin_feature=None, calcifications=None, suture_calcification=None, vascular_feature=None, benign_classification=None, mass_classification=<MassClassification.ill_defined: 'ill_defined'>)]
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.49.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.45.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.46.0
# The number of images is: 1
# The list of marks in the image is: [Mark(id='9663', lesion_id='1', boundingBox=BoundingBox(x1=1, y1=2332, x2=58, y2=2475), conspicuity=<Conspicuity.very_subtle: 'Very_subtle'>, architectural_distortion=None, dystrophic_calcification=None, fat_necrosis=None, focal_asymmetry=True, mass=None, suspicious_calcifications=None, milk_of_calcium=None, other_benign_cluster=None, plasma_cell_mastitis=None, benign_skin_feature=None, calcifications=None, suture_calcification=None, vascular_feature=None, benign_classification=None, mass_classification=None)]
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.50.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.37.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.41.0
# The number of images is: 1
# The list of marks in the image is: []
# The series id is: 1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.34.0
# The number of images is: 1
# The list of marks in the image is: []

# %% [markdown]
# The images are the elemental elements of the dataset (from the point of view of our analysis). <br>
# Image objects contain all the relevant information about the image. <br>
#
# - The image object contains:
#     - The image id: unique for each image
#     - Dicom path
#     - JSON file path with the DICOM metadata
#     - A dictionary containing the DICOM metadata
#     - A parsed version of the DICOM file

# %%
series_ex = study_ex.series[5]
image_num = 0 # usually there is just one image in the series
# get the first image of the series as example
image_ex = series_ex.images[image_num]

print(f'The image id is: {image_ex.id}')
print(f'The dicom path is: {image_ex.dcm_path}')
print(f'The JSON path is: {image_ex.json_path}')
print(f'The list of marks in the image is: {image_ex.marks}')
# Out:
# The image id is: 1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.47.0
# The dicom path is: /mnt/mia_images/breast/omi-db/image_db/sharing/omi-db/images/demd4401/1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.33.0/1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.47.0.dcm
# The JSON path is: /mnt/mia_images/breast/omi-db/image_db/sharing/omi-db/data/demd4401/1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.33.0/1.2.826.0.1.3680043.9.3218.1.1.167619013.2119.1511996139973.47.0.json
# The list of marks in the image is: [Mark(id='9663', lesion_id='1', boundingBox=BoundingBox(x1=1, y1=2332, x2=58, y2=2475), conspicuity=<Conspicuity.very_subtle: 'Very_subtle'>, architectural_distortion=None, dystrophic_calcification=None, fat_necrosis=None, focal_asymmetry=True, mass=None, suspicious_calcifications=None, milk_of_calcium=None, other_benign_cluster=None, plasma_cell_mastitis=None, benign_skin_feature=None, calcifications=None, suture_calcification=None, vascular_feature=None, benign_classification=None, mass_classification=None)]

# %%
# save bbox coordinates in asingle string
x1 = image_ex.marks[0].boundingBox.x1
y1 = image_ex.marks[0].boundingBox.y1
x2 = image_ex.marks[0].boundingBox.x2
y2 = image_ex.marks[0].boundingBox.y2

bbcoords = f'({x1},{y1},{x2},{y2})'
print(bbcoords)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 # save bbox coordinates in asingle string
# ----> 2 x1 = image_ex.marks[0].boundingBox.x1
#       3 y1 = image_ex.marks[0].boundingBox.y1
#       4 x2 = image_ex.marks[0].boundingBox.x2
#
# IndexError: list index out of range

# %%
lesion = image_ex.dcm.pixel_array[y1:y2, x1:x2]
# show lesion
plt.figure()
plt.imshow(lesion, cmap='gray')# plot bounding box on top of original image
plt.figure(figsize=(10,10))
plt.imshow(image_ex.dcm.pixel_array, cmap='gray')
plt.plot([x1,x2,x2,x1,x1],[y1,y1,y2,y2,y1], 'r-')

# %% [markdown]
# # Construction of the dataset

# %% [markdown]
# ## Functions

# %%
class stats:
    """Class for keeping track of the statistics of the dataset
    """
    def __init__(self, N:int, B:int, M:int, IC:int):
        """Initialize the statistics object

        Args:
            N (int): Normal client status
            B (int): Bening client status
            M (int): Malignant client status
            IC (int): Interval Cancer client status
        """
        self.N = N
        self.M = M
        self.B = B
        self.IC = IC # not present
        self.image_CC = 0
        self.image_MLO = 0
        self.image_R = 0
        self.image_L = 0
        self.subtype = np.zeros(8, dtype=np.int32)

    def __repr__(self):
        """when printing the object, print the following:

        Returns:
            str: description of the statistics
        """
        return \
            f'Stats [N: {self.N}, M {self.M}, B: {self.B}, IC {self.IC},'\
            f'CC: {self.image_CC}, MLO: {self.image_MLO}, '\
            f'R: {self.image_R}, L:{self.image_L}, ' \
            f'Subtype: {np.array2string(self.subtype)} ]'

def update_stats_patient(overall:stats, client):

    # Save the general pathological status of the patient:
    #   M: malignant, N:Normal, CI: Interval Cancer
    # In the API, the label is given in the following order of importance:
    # CI > M > B > N
    if client.status.value == 'Interval Cancer': # not present
        overall.IC += 1
    elif client.status.value == 'Malignant':
        overall.M += 1
    elif client.status.value == 'Benign':
        overall.B += 1
    elif client.status.value == 'Normal':
        overall.N += 1
    return overall

# %%
def check_tag_and_value(json_data:dict, tag:str):
    """returns true if the tag is in the json file and has value

    Args:
        json_data (dict): json object with the data
        tag (str): DICOM tag

    Returns:
        bool: true if the tag is in the json file and has value
    """
    return (tag in json_data) and ('Value' in json_data[tag])

def check_presence(json_data:dict):
    """checks if the json file has the required fields

    Args:
        json_data (dict): jason object with the data

    Returns:
        bool: true if the json file has the required fields
    """
    # criteria for selecting images
    for_pres = json_data['00080068']['Value'][0] == 'FOR PRESENTATION' # only images for presentation
    series_descrip = check_tag_and_value(json_data, '0008103E') # check if the series description (side view or other) is defined and has value
    manufacturer = check_tag_and_value(json_data, '00080070') # check if the manufacturer is defined and has value
    fov_type = check_tag_and_value(json_data, '00191039') # check if the fov_type is defined and has value

    if for_pres and (not fov_type): #and series_descrip and manufacturer: # if all the criteria are met, return True
        return True
    else:
        return False

def json_tag2value(json_data:dict, tag:str):
    """returns the value of the tag in the json file

    Args:
        json_data (dict): json object with the data
        tag (str): DICOM tag

    Returns:
        str: value of the tag or None
    """
    if check_tag_and_value(json_data, tag):
        return json_data[tag]['Value'][0]
    else:
        return None

# %% [markdown]
# ## Dataset metadata

# %%
#define the path to the dataset
reading_path = '/mnt/mia_images/breast/omi-db/image_db/sharing/omi-db/'
# db = omidb.DB(reading_path, clients=['demd100018', 'demd128247', 'demd843','demd94678'])
db = omidb.DB(reading_path)

# %% [markdown]
# NBSS data is **client level** information stored in a dictionary, containing:
# - The client id
# - The episodes id (one key per episode)
# - The classification veredict ()

# %% [markdown]
# ### Keeping some visual help

# %%
# create dataframe storing path, presentation type, side, manufacturer, view
df = None

# Initialize the statistics object
overall = stats(0, 0, 0, 0)
for client in tqdm(db, total=len(db.clients)):          # client level
    overall = update_stats_patient(overall, client) # extract the client status for statistics
    nbss_data = db._nbss(client.id) # store nbss data of the client
    # print('=====================================')
    # print(f'Client: {client.id}')
    for episode in client.episodes:                     # episode level
        if episode.studies is not None: # only if the episode has studies
            # print('---------------------------------')
            # print(f'Episode {episode.id}')
            # print('---------------------------------')
            # Episodes may have multiple studies
            # episode_data = nbss_data.get(episode.id, None) # get the nbss data of the episode
            # for key, value in episode_data.items():
            #     if key in ['BIOPSYWIDE', 'SURGERY', 'SCREENING', 'ASSESSMENT']: # for each main information type
            #         for sides_keys, sides_values in value.items(): # inside each of this main information type
            #             if sides_keys=='R' or sides_keys=='L': # if the sides are well defined
            #                 side = sides_keys # define the side
            #                 print(side)
            for study in episode.studies:
                # print('//////////////')
                # print(f'Study {study.event_type}')
                for series in study.series:
                    # print('*************')
                    # print(f'Series {series}')
                    for image in series.images:
                        # print('##############')
                        # add information of current image to dataframe using concat
                        with open(image.json_path, 'r') as f: # open the json file
                            json_data = json.load(f)
                        df = pd.concat(
                            [df, pd.DataFrame(
                            {
                                'client_id': client.id,
                                'episode_id': episode.id,
                                'study_id': study.id,
                                'series_id': series.id,
                                'image_id': image.id,
                                'path': image.dcm_path,
                                'json_path': image.json_path,
                                'presentation': json_data['00080068']['Value'][0],
                                'side': json_data['0008103E']['Value'][0].split(' ')[0],
                                'manufacturer': json_data['00080070']['Value'][0],
                                'view': json_data['0008103E']['Value'][0].split(' ')[1],
                                'magnification': json_data['00191039']['Value'][0] if '00191039' in json_data else None,
                            }, index=[0])], axis=0)
# save the dataframe
df.to_csv('metadata.csv', index=False)
# Out:
# 100%|██████████| 4/4 [00:00<00:00,  5.53it/s]

# %%
# open dataframe
df = pd.read_csv('metadata.csv')
# filter by presentation
df = df[df['presentation']=='FOR PRESENTATION']
df.json_path[0]
# Out:
# '/mnt/mia_images/breast/omi-db/image_db/sharing/omi-db/data/demd128247/1.2.826.0.1.3680043.9.3218.1.1.242302667.45008.1546430561995.2.0/1.2.826.0.1.3680043.9.3218.1.1.242302667.45008.1546430561995.5.0.dcm.json'

# %%
# open dataframe
df = pd.read_csv('metadata.csv')
# filter by presentation
df = df[df['presentation']=='FOR PRESENTATION']
# filter by side
df = df[df['view']=='LM']
for path in df.path:
    # open the dicom file
    print(path)
    dcm = pydicom.dcmread(path)
    # get the image
    image = dcm.pixel_array
    # plot the image
    plt.figure()
    plt.imshow(image, cmap='gray')
# Out:
# /mnt/mia_images/breast/omi-db/image_db/sharing/omi-db/images/demd128247/1.2.826.0.1.3680043.9.3218.1.1.242302667.4500.1546430561995.53.0/1.2.826.0.1.3680043.9.3218.1.1.242302667.4500.1546430561995.63.0.dcm
# /mnt/mia_images/breast/omi-db/image_db/sharing/omi-db/images/demd128247/1.2.826.0.1.3680043.9.3218.1.1.242302667.4500.1546430561995.53.0/1.2.826.0.1.3680043.9.3218.1.1.242302667.4500.1546430561995.66.0.dcm

# %% [markdown]
# ### CSV of *for presentation* images

# %%
# create dataframe storing path, presentation type, side, manufacturer, view
df = None
empty_json = 0

# read dicom tags yaml
with open('metadata/dicom_tags.yaml', 'r') as file:
    tags = yaml.load(file, Loader=yaml.FullLoader)

# Initialize the statistics object
overall = stats(0, 0, 0, 0)
for client in tqdm(db, total=len(db.clients)):          #@ client level
    overall = update_stats_patient(overall, client) # extract the client status for statistics
    nbss_data = db._nbss(client.id) # store nbss data of the client
    for episode in client.episodes:                     #@ episode level
        if episode.studies is not None: # only if the episode has studies
            for study in episode.studies:               #@ study level
                for series in study.series:             #@ series level
                    for image in series.images:         #@ image level
                        with open(image.json_path, 'r') as file: # open the image json file
                            if file.read() != '': # check the file is not empty
                                file.seek(0) # go back to the beginning of the file
                                json_data = json.load(file)
                            else:
                                empty_json += 1
                        # check if the json file has the relevant information
                        if check_presence(json_data): # if the image is for presentation
                            # object oriented information storage
                            df_sub = pd.DataFrame(
                                {
                                    'client_id': client.id,
                                    'episode_id': episode.id,
                                    'study_id': study.id,
                                    'series_id': series.id,
                                    'image_id': image.id,
                                    'path': image.dcm_path,
                                    'json_path': image.json_path,
                                    'client_status': client.status.value,
                                }, index=[0])
                            # go through the tags and save the json-contained information
                            for tag in tags:
                                df_sub = pd.concat([df_sub, pd.DataFrame({tag: json_tag2value(json_data, tags[tag])}, index=[0])], axis=1)
                            # concat in general df
                            df = pd.concat(
                                [df, df_sub], axis=0)                        

# save the dataframe
df.to_csv('metadata/metadata_FP.csv', index=False)

# print the statistics
subclients_num =  len(df['client_id'].unique())
print(f'Number of valid clients: {subclients_num}')
print(f'Images with no valid json file: {empty_json}')
# Out:
#  24%|██▍       | 1454/6000 [09:09<28:37,  2.65it/s]
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_1223254/3938743672.py", line -1, in <module>
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/home/ricardo/miniconda3/envs/iceberg/lib/python3.10/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %% [markdown]
# The whole dataset size.
